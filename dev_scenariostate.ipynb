# %%
import pandas as pd
from functions.calc_funcs import calculate_amortization_schedule
from classes.state_manager import ScenarioState

# Create a sample DataFrame
data = {
    'monthly_loan_payment': [1000],
    'a_total': [20000],
    'b_total': [30000],
    'ownership_fraq': [0.5]
}
df = pd.DataFrame(data)

# Create an instance of the ScenarioState class and set its attributes
scenario = ScenarioState(
    df=df,
    selected_house_price=500000.0,
    selected_interest_rate=0.05,
    total_loan=400000.0,
    monthly_payment=1000.0,
    total_interest=354000.0,
    loan_to_value=80.0,
    total_cost_a=20000.0,
    total_cost_b=30000.0,
    loan_amount=400000.0,
    ownership_fraq=0.5,
    loan_amount_a=200000.0,
    loan_amount_b=200000.0,
    schedule_a=None,
    schedule_b=None,
    calculation_done=False
)

# Update the scenario with new data
scenario.update(df, 500000.0, 100000.0, 360.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 35
#      15 scenario = ScenarioState(
#      16     df=df,
#      17     selected_house_price=500000.0,
#    (...)
#      31     calculation_done=False
#      32 )
#      34 # Update the scenario with new data
# ---> 35 scenario.update(df, 500000.0, 100000.0, 360.0)
#
# File e:\Anaconda\envs\dev\Lib\site-packages\pydantic\validate_call_decorator.py:60, in validate_call.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      58 @functools.wraps(function)
#      59 def wrapper_function(*args, **kwargs):
# ---> 60     return validate_call_wrapper(*args, **kwargs)
#
# File e:\Anaconda\envs\dev\Lib\site-packages\pydantic\_internal\_validate_call.py:96, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#      95 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# ---> 96     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#      97     if self.__return_pydantic_validator__:
#      98         return self.__return_pydantic_validator__(res)
#
# File e:\Coding projects\Git repos\boligpriskalkulator\boligpriskalkulator\classes\state_manager.py:128, in ScenarioState.update(self, filtered_df, selected_house_price, ek, ammortisation_periods)
#     125 self.loan_amount_b = self.loan_amount * (1 - self.ownership_fraq)
#     127 # Assume calculate_amortization_schedule is imported or defined elsewhere
# --> 128 self.schedule_a = calculate_amortization_schedule(
#     129     self.loan_amount_a, self.selected_interest_rate, ammortisation_periods
#     130 )
#     131 self.schedule_b = calculate_amortization_schedule(
#     132     self.loan_amount_b, self.selected_interest_rate, ammortisation_periods
#     133 )
#     134 self.calculation_done = True
#
# File e:\Coding projects\Git repos\boligpriskalkulator\boligpriskalkulator\functions\calc_funcs.py:60, in calculate_amortization_schedule(loan_amount, annual_interest_rate, loan_term_months)
#      57 monthly_rate = annual_interest_rate / 12
#      58 monthly_payment = npf.pmt(monthly_rate, loan_term_months, -loan_amount)
# ---> 60 remaining_balance = np.full(loan_term_months, loan_amount)
#      61 interest_payment = remaining_balance * monthly_rate
#      62 principal_payment = monthly_payment - interest_payment
#
# File e:\Anaconda\envs\dev\Lib\site-packages\numpy\_core\numeric.py:365, in full(shape, fill_value, dtype, order, device, like)
#     363     fill_value = asarray(fill_value)
#     364     dtype = fill_value.dtype
# --> 365 a = empty(shape, dtype, order, device=device)
#     366 multiarray.copyto(a, fill_value, casting='unsafe')
#     367 return a
#
# TypeError: expected a sequence of integers or a single integer, got '360.0'

# %%
scenario.model_dump()
# Out:
# {'df':    monthly_loan_payment  a_total  b_total  ownership_fraq
#  0                  1000    20000    30000             0.5,
#  'selected_house_price': 500000.0,
#  'selected_interest_rate': 0.05,
#  'total_loan': 400000.0,
#  'monthly_payment': 1000,
#  'total_interest': -40000.0,
#  'loan_to_value': 80.0,
#  'total_cost_a': 20000,
#  'total_cost_b': 30000,
#  'loan_amount': 400000.0,
#  'ownership_fraq': 0.5,
#  'loan_amount_a': 200000.0,
#  'loan_amount_b': 200000.0,
#  'schedule_a':      Month      Payment    Principal    Interest  Remaining Balance
#  0        1  1073.643246   240.309913  833.333333       1.997597e+05
#  1        2  1073.643246   241.311204  832.332042       1.995184e+05
#  2        3  1073.643246   242.316667  831.326579       1.992761e+05
#  3        4  1073.643246   243.326320  830.316926       1.990327e+05
#  4        5  1073.643246   244.340180  829.303066       1.987884e+05
#  ..     ...          ...          ...         ...                ...
#  355    356  1073.643246  1051.552577   22.090669       4.250208e+03
#  356    357  1073.643246  1055.934046   17.709200       3.194274e+03
#  357    358  1073.643246  1060.333771   13.309475       2.133940e+03
#  358    359  1073.643246  1064.751829    8.891417       1.069188e+03
#  359    360  1073.643246  1069.188295    4.454951      -1.671197e-09
#
#  [360 rows x 5 columns],
#  'schedule_b':      Month      Payment    Principal    Interest  Remaining Balance
#  0        1  1073.643246   240.309913  833.333333       1.997597e+05
#  1        2  1073.643246   241.311204  832.332042       1.995184e+05
#  2        3  1073.643246   242.316667  831.326579       1.992761e+05
#  3        4  1073.643246   243.326320  830.316926       1.990327e+05
#  4        5  1073.643246   244.340180  829.303066       1.987884e+05
#  ..     ...          ...          ...         ...                ...
#  355    356  1073.643246  1051.552577   22.090669       4.250208e+03
#  356    357  1073.643246  1055.934046   17.709200       3.194274e+03
#  357    358  1073.643246  1060.333771   13.309475       2.133940e+03
#  358    359  1073.643246  1064.751829    8.891417       1.069188e+03
#  359    360  1073.643246  1069.188295    4.454951      -1.671197e-09
#
#  [360 rows x 5 columns],
#  'calculation_done': True}

# %%
# %%timeit
# Update the scenario with new data
scenario.update(df, 500000.0, 100000.0, 360.0)
# Out:
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# ...
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 200000.0 0.05 360
# 1.15 ms ± 23 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
calculate_amortization_schedule(500000.0, 0.5, 360)
# Out:
# 420 μs ± 4.69 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
from functions.calc_funcs import monthly_price_calculator_scenarios

def create_sample_data():
    # Use monthly_price_calculator_scenarios to generate realistic data
    df = monthly_price_calculator_scenarios(
        houseprice_range=np.arange(3000000, 5000001, 100000),
        interest_rate_range=np.arange(0.01, 0.06, 0.0025),
        fixed_cost_house_range=[5000],
        kwh_usage_range=[500],
        kwh_price_range=[1.5],
        markup_nok_range=[0.1],
        fixed_cost_electricity_range=[39],
        ammortisation_periods_range=[360],
        person_a_fixed_costs_range=[10000],
        person_b_fixed_costs_range=[10000],
        transaction_costs_range=[200000],
        ek_range=[1500000],
        ownership_fraq_range=[0.5]
    )
    
    # Sample row for sunburst chart
    sample_row = df.iloc[0]
    
    # Prepare data for cost breakdown sunburst
    sunburst_data = pd.DataFrame({
        'kategori': ['Boligkostnader', 'Boligkostnader', 'Boligkostnader', 'Personlige kostnader'],
        'underkategori': ['Lånebetaling', 'Faste boligkostnader', 'Strøm', 'Andre faste kostnader'],
        'verdi': [
            sample_row['monthly_loan_payment'] * sample_row['ownership_fraq'],
            sample_row['fixed_cost_house'] / 2,
            sample_row['el_cost'] / 2,
            sample_row['person_a_fixed_costs']
        ]
    })
    
    # Data for interest rate sensitivity chart
    loan_amount = sample_row['house_price'] - 1500000  # Assuming ek is 1500000
    amortization_periods = 360
    interest_rate_range = df['interest_rate'].unique()
    
    # Data for amortization chart
    amortization_schedule = calculate_amortization_schedule(
        loan_amount, 
        sample_row['interest_rate'], 
        amortization_periods
    )
    
    return sunburst_data #loan_amount, amortization_periods, interest_rate_range, amortization_schedule, df

# %%
import numpy as np
create_sample_data()
# Out:
#                kategori          underkategori         verdi
# 0        Boligkostnader           Lånebetaling   2733.935924
# 1        Boligkostnader   Faste boligkostnader   2500.000000
# 2        Boligkostnader                  Strøm    287.312500
# 3  Personlige kostnader  Andre faste kostnader  10000.000000
